# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
import time
import matplotlib.pyplot as plt 
import random
import csv

# %%
pd.set_option('display.max_rows',300)
pd.set_option('display.max_columns',100)
pd.set_option('max_colwidth',800)

plt.figure(figsize=(20,10))

# %%
android_dev = pd.read_csv('../model_dataset/android_dev.csv')

# %%
android_dev
# Out:
#                                                      Job_Name  \
# 0                                           Android Developer
# 1    Urgent Opening For Android Developer (Immediate Joining)
# 2                                           Android Developer
# 3                                       Sr. Android Developer
# 4                                    Remote Android Developer
# ..                                                        ...
# 470                                         Android Developer
# 471                                     Sr. Android Developer
# 472                                         Android Developer
# 473                                  Senior Android Developer
# 474                             Android Application Developer
#
#                              Company_Name                         Location  \
# 0                              Arham Labs              Mumbai, Maharashtra
# 1                          Prolifiquetech  Vashi, Navi Mumbai, Maharashtra
# 2                 City Dreams Enterprises                          Gujarat
# 3                        CREATIVE INFOWAY                          Gujarat
# 4                     Rishabh Group India           Ujjain, Madhya Pradesh
# ..                                    ...                              ...
# 470                   AUM Telecom Pvt Ltd             Hyderabad, Telangana
# 471                            V-ROBOTICS             Noida, Uttar Pradesh
# 472                   SCSoft Technologies                Pune, Maharashtra
# 473                      Neolite Infotech                Pune, Maharashtra
# 474  eSearch Logix Technologies Pvt. Ltd.                Pune, Maharashtra
#
#                                                                                                                                              Skills  \
# 0    JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 1    JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 2    JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 3    JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 4    JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# ..                                                                                                                                              ...
# 470  JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 471  JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 472  JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 473  JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
# 474  JAVA,UNDERSTANDING OF XML,ANDROID SDK,ANDROID STUDIO,APIS,DATABASES,MATERIAL DESIGN,Kotlin,UX/UI,Critical Thinking,Cross-Platform,Adaptability
#
#      Yearly Salary
# 0         350000.0
# 1         350000.0
# 2         360000.0
# 3         330000.0
# 4         300000.0
# ..             ...
# 470       730000.0
# 471       610000.0
# 472       770000.0
# 473       690000.0
# 474       530000.0
#
# [475 rows x 5 columns]
