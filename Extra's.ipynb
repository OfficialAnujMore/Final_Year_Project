# %% [markdown]
# # Extra's

# %%
# [android_dev, ai, backend_dev, business_analyst, cloud_computing, data_analyst, data_scientist, deep_learning, devops, 
# full_stack_dev, game_artist, game_designer, iOS_dev, java_dev, ml, mean, mern, net_security_engg,
# node_js, php_dev, py_dev, react_js, react_native_dev, sys_admin, ui_ux, web_dev]

# -----------------------------------------------------------------------------------------------------------------------------

# android_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# ai.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# backend_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# business_analyst.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# cloud_computing.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# data_analyst.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# data_scientist.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# deep_learning.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# devops.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# flutter_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# full_stack_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# game_artist.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# game_designer.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# iOS_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# java_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# ml.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# mean.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# mern.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# net_security_engg.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# node_js.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# php_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# py_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# react_js.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# react_native_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# sys_admin.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# ui_ux.drop_duplicates(subset="Description", keep= 'first', inplace=True)
# web_dev.drop_duplicates(subset="Description", keep= 'first', inplace=True)

# -----------------------------------------------------------------------------------------------------------------------------


# android_dev
# ai
# backend_dev
# business_analyst
# cloud_computing
# data_analyst
# data_scientist
# deep_learning
# devops
# flutter_dev
# full_stack_dev
# game_artist
# game_designer
# iOS_dev
# java_dev
# ml
# mean
# mern
# net_security_engg
# node_js
# php_dev
# py_dev
# react_js
# react_native_dev
# sys_admin
# ui_ux
# web_dev

# -----------------------------------------------------------------------------------------------------------------------------


# android_dev.shape
# ai.shape
# backend_dev.shape
# business_analyst.shape
# cloud_computing.shape
# data_analyst.shape
# data_scientist.shape
# deep_learning.shape
# devops.shape
# flutter_dev.shape
# full_stack_dev.shape
# game_artist.shape
# game_designer.shape
# iOS_dev.shape
# java_dev.shape
# ml.shape
# mean.shape
# mern.shape
# net_security_engg.shape
# node_js.shape
# php_dev.shape
# py_dev.shape
# react_js.shape
# react_native_dev.shape
# sys_admin.shape
# ui_ux.shape
# web_dev.shape


# -----------------------------------------------------------------------------------------------------------------------------


# android_dev['Salary'].fillna('',inplace=True)
# android_dev

# ai['Salary'].fillna('',inplace=True)
# ai

# backend_dev['Salary'].fillna('',inplace=True)
# backend_dev

# business_analyst['Salary'].fillna('',inplace=True)
# business_analyst

# cloud_computing['Salary'].fillna('',inplace=True)
# cloud_computing

# data_analyst['Salary'].fillna('',inplace=True)
# data_analyst

# data_scientist['Salary'].fillna('',inplace=True)
# data_scientist

# deep_learning['Salary'].fillna('',inplace=True)
# deep_learning

# devops['Salary'].fillna('',inplace=True)
# devops

# full_stack_dev['Salary'].fillna('',inplace=True)
# full_stack_dev

# game_artist['Salary'].fillna('',inplace=True)
# game_artist

# game_designer['Salary'].fillna('',inplace=True)
# game_designer

# iOS_dev['Salary'].fillna('',inplace=True)
# iOS_dev

# java_dev['Salary'].fillna('',inplace=True)
# java_dev

# ml['Salary'].fillna('',inplace=True)
# ml

# mean['Salary'].fillna('',inplace=True)
# mean

# mern['Salary'].fillna('',inplace=True)
# mern

# net_security_engg['Salary'].fillna('',inplace=True)
# net_security_engg

# node_js['Salary'].fillna('',inplace=True)
# node_js

# php_dev['Salary'].fillna('',inplace=True)
# php_dev

# py_dev['Salary'].fillna('',inplace=True)
# py_dev

# react_js['Salary'].fillna('',inplace=True)
# react_js

# react_native_dev['Salary'].fillna('',inplace=True)
# react_native_dev

# sys_admin['Salary'].fillna('',inplace=True)
# sys_admin

# ui_ux['Salary'].fillna('',inplace=True)
# ui_ux

# web_dev['Salary'].fillna('',inplace=True)
# web_dev



# -----------------------------------------------------------------------------------------------------------------------------


    
# android_dev['Yearly Salary'] = android_dev['Salary'].apply(Salary_Cleaning)
    
# ai['Yearly Salary'] = ai['Salary'].apply(Salary_Cleaning)
    
# backend_dev['Yearly Salary'] = backend_dev['Salary'].apply(Salary_Cleaning)
    
# business_analyst['Yearly Salary'] = business_analyst['Salary'].apply(Salary_Cleaning)
    
# cloud_computing['Yearly Salary'] = cloud_computing['Salary'].apply(Salary_Cleaning)
    
# data_analyst['Yearly Salary'] = data_analyst['Salary'].apply(Salary_Cleaning)
    
# data_scientist['Yearly Salary'] = data_scientist['Salary'].apply(Salary_Cleaning)
    
# deep_learning['Yearly Salary'] = deep_learning['Salary'].apply(Salary_Cleaning)
    
# devops['Yearly Salary'] = devops['Salary'].apply(Salary_Cleaning)
    
# full_stack_dev['Yearly Salary'] = full_stack_dev['Salary'].apply(Salary_Cleaning)
    
# game_artist['Yearly Salary'] = game_artist['Salary'].apply(Salary_Cleaning)
    
# game_designer['Yearly Salary'] = game_designer['Salary'].apply(Salary_Cleaning)

# iOS_dev['Yearly Salary'] = iOS_dev['Salary'].apply(Salary_Cleaning)
    
# java_dev['Yearly Salary'] = java_dev['Salary'].apply(Salary_Cleaning)
    
# ml['Yearly Salary'] = ml['Salary'].apply(Salary_Cleaning)
    
# mean['Yearly Salary'] = mean['Salary'].apply(Salary_Cleaning)
    
# mern['Yearly Salary'] = mern['Salary'].apply(Salary_Cleaning)
    
# net_security_engg['Yearly Salary'] = net_security_engg['Salary'].apply(Salary_Cleaning)
    
# node_js['Yearly Salary'] = node_js['Salary'].apply(Salary_Cleaning)
    
# php_dev['Yearly Salary'] = php_dev['Salary'].apply(Salary_Cleaning)
    
# py_dev['Yearly Salary'] = py_dev['Salary'].apply(Salary_Cleaning)
    
# react_js['Yearly Salary'] = react_js['Salary'].apply(Salary_Cleaning)
    
# react_native_dev['Yearly Salary'] = react_native_dev['Salary'].apply(Salary_Cleaning)
    
# sys_admin['Yearly Salary'] = sys_admin['Salary'].apply(Salary_Cleaning)

# ui_ux['Yearly Salary'] = ui_ux['Salary'].apply(Salary_Cleaning)
    
# web_dev['Yearly Salary'] = web_dev['Salary'].apply(Salary_Cleaning)\

# -----------------------------------------------------------------------------------------------------------------------------


# for i in range(0,1):
#     print(android_dev['Yearly Salary'].mean())
#     print(ai["Yearly Salary"].mean())

# -----------------------------------------------------------------------------------------------------------------------------


# android_dev['Yearly Salary'] = android_dev['Yearly Salary'].apply(Lower_Salary)
    
# ai['Yearly Salary'] = ai['Yearly Salary'].apply(Lower_Salary)
    
# backend_dev['Yearly Salary'] = backend_dev['Yearly Salary'].apply(Lower_Salary)
    
# business_analyst['Yearly Salary'] = business_analyst['Yearly Salary'].apply(Lower_Salary)
    
# cloud_computing['Yearly Salary'] = cloud_computing['Yearly Salary'].apply(Lower_Salary)
    
# data_analyst['Yearly Salary'] = data_analyst['Yearly Salary'].apply(Lower_Salary)
    
# data_scientist['Yearly Salary'] = data_scientist['Yearly Salary'].apply(Lower_Salary)
    
# deep_learning['Yearly Salary'] = deep_learning['Yearly Salary'].apply(Lower_Salary)
    
# devops['Yearly Salary'] = devops['Yearly Salary'].apply(Lower_Salary)
    
# full_stack_dev['Yearly Salary'] = full_stack_dev['Yearly Salary'].apply(Lower_Salary)
    
# game_artist['Yearly Salary'] = game_artist['Yearly Salary'].apply(Lower_Salary)
    
# game_designer['Yearly Salary'] = game_designer['Yearly Salary'].apply(Lower_Salary)

# iOS_dev['Yearly Salary'] = iOS_dev['Yearly Salary'].apply(Lower_Salary)
    
# java_dev['Yearly Salary'] = java_dev['Yearly Salary'].apply(Lower_Salary)
    
# ml['Yearly Salary'] = ml['Yearly Salary'].apply(Lower_Salary)
    
# mean['Yearly Salary'] = mean['Yearly Salary'].apply(Lower_Salary)
    
# mern['Yearly Salary'] = mern['Yearly Salary'].apply(Lower_Salary)
    
# net_security_engg['Yearly Salary'] = net_security_engg['Yearly Salary'].apply(Lower_Salary)
    
# node_js['Yearly Salary'] = node_js['Yearly Salary'].apply(Lower_Salary)
    
# php_dev['Yearly Salary'] = php_dev['Yearly Salary'].apply(Lower_Salary)
    
# py_dev['Yearly Salary'] = py_dev['Yearly Salary'].apply(Lower_Salary)
    
# react_js['Yearly Salary'] = react_js['Yearly Salary'].apply(Lower_Salary)
    
# react_native_dev['Yearly Salary'] = react_native_dev['Yearly Salary'].apply(Lower_Salary)
    
# sys_admin['Yearly Salary'] = sys_admin['Yearly Salary'].apply(Lower_Salary)

# ui_ux['Yearly Salary'] = ui_ux['Yearly Salary'].apply(Lower_Salary)
    
# web_dev['Yearly Salary'] = web_dev['Yearly Salary'].apply(Lower_Salary)

# -----------------------------------------------------------------------------------------------------------------------------



# def Mean_calculator(dataframe_name):
#     for i in range(0,len(dataframe_name)):
#         try:
#             mean_value = float(round(dataframe_name[i]['Yearly Salary'].mean()))
#             print(mean_value)

#             dataframe_name[i]['Yearly Salary'] = dataframe_name[i]['Yearly Salary'].fillna(mean_value)
        
#         except exception as e:
#             print(e)
#             return e
# Mean_calculator(filename)       

# -----------------------------------------------------------------------------------------------------------------------------


# def heatmap_generator_for_nan(dataframe_name):
#     for i in range(0,len(dataframe_name)):
#         sns.heatmap(dataframe_name[i].isnull())
#         time.sleep(5)
    
# heatmap_generator_for_nan(filename)
